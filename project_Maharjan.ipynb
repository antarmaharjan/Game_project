# %%
Create a program where the user can play a game of rock, 
paper, scissors against a computer. Set a play choice 
(rock, paper, or scissors) for the computer player and during the program,
request for the user to input their play choice.
The rules in Rock, Paper, Scissors are:

Rock beats scissors
Scissors beats paper
Paper beats rock
If the user wins, then display "You win!" If they lose against the computer,
then display "You lose." If the computer and the user have the same play choice, display "It's a draw."

BONUS: Randomize the play choice for the computer (hint: Python has a library
called random). Also ask the user if they would like to play again. If they do, start the game again but if not, thank the user for playing the game.

# %%
import random
comp_wins =0
player_wins=0

def Choose_option():
    user_choice =input("Please choose Rock,Paper or Scissors: ")
    if user_choice in ("Rock", "rock", "R", "r" ):
        user_choice="r"
    elif user_choice in ("paper", "Paper", "P", "p"):
        user_choice ="p"
    elif user_choice in ("Scissors", "scissors", "s", "S"):
        user_choice ="s"
    else:
        print("I don't understand, try again")
        Choose_option()
    return user_choice

def Comp_Option():
    comp_choice =random.randint(1,3)
    if comp_choice ==1:
        comp_choice ="r"
    elif comp_choice ==2:
        comp_choice ="p"
    else:
        comp_choice ="s"
    return comp_choice

while True:
    print("")
    user_choice =Choose_option()
    comp_choice = Comp_Option()
    print("")
    
    if user_choice =="r":
        if comp_choice =="r":
            print("Both chose the same. So It is draw")
        elif comp_choice =="p":
            print("you chose the rock. the computer chose the paper. you lost")
            comp_wins +=1
        elif comp_choice =="s":
            print("you chose the rock. the computer chose the scissors. you won")
            player_wins +=1
            
    elif user_choice =="p":
        if comp_choice =="r":
            print("You chose paper. The computer chose rock. you won")
            player_wins +=1
        elif comp_choice =="p":
            print("you chose the paper. the computer chose the paper. it's draw")
           
        elif comp_choice =="s":
            print("you chose the paper. the computer chose the scissors. you lost")
            comp_wins +=1
            
    elif user_choice =="s":
        if comp_choice =="r":
            print("You chose scissors. The computer chose rock. you lost")
            comp_wins +=1
        elif comp_choice =="p":
            print("you chose the scissors. the computer chose the paper. you won")
            player_wins +=1
           
        elif comp_choice =="s":
            print("you chose the scissors. the computer chose the scissors. it's draw")
            
        print("")
        print("player wins: "+str(player_wins))
        print("Computer wins: "+str(comp_wins))
        
        user_choice=input("Do you want to play again?(y/n)")
        if user_choice in ["Y","y","Yes", "yes"]:
                          pass
        elif user_choice in ["N","n","No","n"]:
                          break
# Out:
# Please choose Rock,Paper or Scissors: p
#
# you chose the paper. the computer chose the scissors. you lost
#
# Please choose Rock,Paper or Scissors: s
#
# you chose the scissors. the computer chose the paper. you won
#
# player wins: 1
# Computer wins: 1
# Do you want to play again?(y/n)y
#
# Please choose Rock,Paper or Scissors: p
#
# You chose paper. The computer chose rock. you won
#
# Please choose Rock,Paper or Scissors: o
# I don't understand, try again
# Please choose Rock,Paper or Scissors: p
#
#
# Please choose Rock,Paper or Scissors: r
#
# you chose the rock. the computer chose the scissors. you won
